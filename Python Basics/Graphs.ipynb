# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [2,4,6]

plt.scatter(x,y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]
plt.plot(x2,y2,"r--") # the first character of this string decides the color of the line. Second character decides type of line

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]
plt.plot(x2,y2,"r+") # the first character of this string decides the color of the line. Second character decides type of line

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]
plt.plot(x2,y2,"r^") # the first character of this string decides the color of the line. Second character decides type of line

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]
plt.plot(x2,y2,"rp") # the first character of this string decides the color of the line. Second character decides type of line

plt.plot(x,y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]
x2 = [3,4,5]
y2 = [2,4,6]
plt.plot(x2,y2,"r-.") # the first character of this string decides the color of the line. Second character decides type of line

plt.plot(x,y)
plt.show()

# %%
# Plotting function x ^3
import numpy as np
x = np.array([1,2,3])
y = x**3
plt.plot(x,y)
plt.show()

# %%
x1 = np.arange(0,5,0.1)
y = x1**3
plt.plot(x1,y)
plt.show()

# %%
x1 = np.arange(0,5,0.1)
y = x1**3
plt.plot(x1,y,"ro")
plt.show()

# %%
a = [2,3,4]
plt.plot(a) # here a is taken as y axis and for x axis it takes range(len(a))
plt.show()

# %% [markdown]
# # Customizing Graphs

# %%
x1 = np.arange(0,5,0.1)
y = x1**3
plt.plot(x1,y,color = "black")
plt.show()

# %%
x1 = np.arange(0,5,0.1)
y = x1**3
plt.plot(x1,y,color = "black",marker="o") # marker gives the points along with the line unlike "ro"
plt.show()

# %%
x1 = np.arange(0,5,0.1)
y = x1**3
plt.plot(x1,y,color = "black",linewidth = 5)
plt.show()

# %%
x1 = np.arange(0,5,0.1)
y = x1**3
y2 = x1 ** 2
plt.plot(x1,y,color = "red",marker="o",label = "X^3") # marker gives the points along with the line unlike "ro"
plt.plot(x1,y2,color = "blue",marker="p",label = "X^2")
plt.axis([0,10,0,150]) # 4 enteries
plt.grid()
plt.ylabel("Y")
plt.xlabel("X")
plt.title("Demo Graph")
plt.legend() # required for us to show the legends we passed in plt.plot() function
plt.show()

# %%
# Adding random text at some place in graph
x1 = np.arange(0,5,0.1)
y = x1**3
y2 = x1 ** 2
plt.plot(x1,y,color = "red",marker="o",label = "X^3") # marker gives the points along with the line unlike "ro"
plt.plot(x1,y2,color = "blue",marker="p",label = "X^2")
plt.axis([0,10,0,150]) # 4 enteries
plt.grid()
plt.ylabel("Y")
plt.xlabel("X")
plt.title("Demo Graph")
plt.legend() # required for us to show the legends we passed in plt.plot() function
plt.text(2,80,"Demo Random Text",fontsize = 30) 
plt.show()

# %% [markdown]
# # PIE Graphs

# %%
sizes = [3,4,6,2]
labels = ["A","B","C","D"]
colors = ["blue","black","red","pink"]
plt.title("Split among diff classes")
plt.pie(sizes,colors = colors,labels = labels)
plt.axis("equal")
plt.show()

# %%
sizes = [3,4,6,2]
labels = ["A","B","C","D"]
colors = ["blue","purple","red","pink"]
explode = [0.1,0,0,0] # if 1 then completly comes out
plt.title("Split among diff classes")
plt.pie(sizes,colors = colors,explode = explode,labels = labels,autopct="%.1f%%") # one point after decimal
plt.axis("equal")
plt.show()

# %%
# BY DEFAULT PIE GRAPH IS ANTI CLOCKWISE, TO MAKE IT CLOCKWISE
sizes = [3,4,6,2]
labels = ["A","B","C","D"]
colors = ["blue","purple","red","pink"]
explode = [0.1,0,0,0] # if 1 then completly comes out
plt.title("Split among diff classes")
plt.pie(sizes,colors = colors,explode = explode,labels = labels,autopct="%.1f%%",counterclock = False) # one point after decimal
plt.axis("equal")
plt.show()

# %%
sizes = [3,4,6,2]
labels = ["A","B","C","D"]
colors = ["blue","purple","red","pink"]
explode = [0.1,0,0,0] # if 1 then completly comes out
plt.title("Split among diff classes")
plt.pie(sizes,colors = colors,explode = explode,labels = labels,autopct="%.1f%%",counterclock = False,startangle = 100) # one point after decimal
plt.axis("equal")
plt.show()
